# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('D:\\IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.countplot(x='species',data=df)

# %%
sns.pairplot(df,hue='species')

# %%
df.size
# Out:
# 750

# %%
df=df.dropna()

# %%
df.size
# Out:
# 750

# %%
X=df[['sepal_length','sepal_width','petal_length','petal_width']].values
y=df[['species']].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=5)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(learning_rate=0.01,n_estimators=200).fit(x_train,y_train)
# Out:
# C:\Users\sudee\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1454: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_predic=gbc.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,y_predic))
# Out:
# [[12  0  0]
#  [ 0 13  1]
#  [ 0  1 11]]

# %%
print(classification_report(y_test,y_predic))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.93      0.93      0.93        14
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.95      0.95        38
#    weighted avg       0.95      0.95      0.95        38
